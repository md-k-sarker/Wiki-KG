# %%
import pandas as pd
import numpy as np

# %%
indiv_csv = '/Users/sarker/Workspaces/Jetbrains/wiki_analysis/data/indivs_mapped_v1.csv'
concept_csv = '/Users/sarker/Workspaces/Jetbrains/wiki_analysis/data/concepts_mapped_v1.csv'

# %%
df_indiv = pd.read_csv(indiv_csv)
len(set(df_indiv['wikiTypes']))
# Out:
# 42660

# %%
df_concept = pd.read_csv(concept_csv)

# %%
# any match in concept hierarchy
for concept,sumoTypes,wikiTypes in zip(df_concept['concept'],df_concept['sumoTypes'],df_concept['wikiTypes']):
    if sumoTypes and wikiTypes:
        s_types = [s for s in sumoTypes.split(';') if len(s)>1]
        w_types = [s for s in wikiTypes.split(';') if len(s)>1]
        print(s_types, w_types)
# Out:
# wikiTypes:  Grape;Fermented_drinks;
# ['AlcoholicBeverage', 'Beverage', 'PlantAgriculturalProduct'] ['Grape', 'Fermented_drinks']
# wikiTypes:  Circulatory_system;
# ['AnimalAnatomicalStructure', 'Organ'] ['Circulatory_system']
# wikiTypes:  Lubricants;Transparent_materials;Liquid_dielectrics;Refrigerants;
# ['CompoundSubstance'] ['Lubricants', 'Transparent_materials', 'Liquid_dielectrics', 'Refrigerants']
# wikiTypes:  Chemical_elements;
# ['ElementalSubstance'] ['Chemical_elements']
# wikiTypes:  Meteorological_phenomena;
# ['GasMotion'] ['Meteorological_phenomena']
# wikiTypes:  Production_and_manufacturing;
# ['Artifact'] ['Production_and_manufacturing']
# wikiTypes:  Chemical_elements;
# ['ElementalSubstance'] ['Chemical_elements']
# wikiTypes:  Five_Pillars_of_Islam;Taxation_in_Islam;Alms_in_Islam;
# ['ReligiousProcess'] ['Five_Pillars_of_Islam', 'Taxation_in_Islam', 'Alms_in_Islam']
# wikiTypes:  Chemical_elements;
# ['ElementalSubstance'] ['Chemical_elements']
# wikiTypes:  Diseases_and_disorders;
# ['AbnormalAnatomicalStructure'] ['Diseases_and_disorders']
# wikiTypes:  Chemical_elements;
# ['ElementalSubstance'] ['Chemical_elements']
# wikiTypes:  Months;
# ['Month'] ['Months']
# wikiTypes:  Geomorphology;
# ['Removing', 'GeologicalProcess'] ['Geomorphology']
# wikiTypes:  Dairy_products;
# ['LiquidBodySubstance', 'DairyProduct', 'Beverage'] ['Dairy_products']
# wikiTypes:  Organ_systems;
# ['AnimalAnatomicalStructure'] ['Organ_systems']
# wikiTypes:  Feasts_of_Jesus_Christ;
# ['MoveableHoliday', 'ChristianHoliday', 'Sunday'] ['Feasts_of_Jesus_Christ']
# wikiTypes:  Social_research;Public_opinion;
# ['Investigating'] ['Social_research', 'Public_opinion']
# wikiTypes:  Noble_gases;Chemical_elements;
# ['ElementalSubstance'] ['Noble_gases', 'Chemical_elements']
# wikiTypes:  Crops;Livestock;
# ['OrganicObject'] ['Crops', 'Livestock']
# wikiTypes:  Qualia;Hearing;
# ['BodyOfWater'] ['Qualia', 'Hearing']
# wikiTypes:  Chemical_elements;
# ['ElementalSubstance'] ['Chemical_elements']
# wikiTypes:  Islamic_worship;Five_Pillars_of_Islam;
# ['Translocation', 'ReligiousProcess'] ['Islamic_worship', 'Five_Pillars_of_Islam']
# wikiTypes:  Human_activities;
# ['IntentionalPsychologicalProcess'] ['Human_activities']
# wikiTypes:  Construction;
# ['StationaryArtifact'] ['Construction']
# wikiTypes:  Months;
# ['Month'] ['Months']
# wikiTypes:  Fruits_originating_in_South_America;Tropical_fruit;Fruits_originating_in_North_America;
# ['TropicalFruit'] ['Fruits_originating_in_South_America', 'Tropical_fruit', 'Fruits_originating_in_North_America']
# wikiTypes:  Chemical_elements;
# ['ElementalSubstance'] ['Chemical_elements']
# wikiTypes:  Chemical_elements;
# ['ElementalSubstance'] ['Chemical_elements']
# wikiTypes:  Brewing;
# ['AlcoholicBeverage'] ['Brewing']
# wikiTypes:  Months;
# ['Month'] ['Months']
# wikiTypes:  Chemical_elements;Nuclear_fuels;Nuclear_materials;
# ['ElementalSubstance'] ['Chemical_elements', 'Nuclear_fuels', 'Nuclear_materials']
# wikiTypes:  Marketing;
# ['Working'] ['Marketing']
# wikiTypes:  Politics;
# ['Deciding'] ['Politics']
# wikiTypes:  Severe_weather_and_convection;Storm;Weather_hazards;
# ['WeatherProcess'] ['Severe_weather_and_convection', 'Storm', 'Weather_hazards']
# wikiTypes:  Cattle_products;Livestock;Meat_by_animal;
# ['Meat'] ['Cattle_products', 'Livestock', 'Meat_by_animal']
# wikiTypes:  Leaf_vegetables;
# ['Vegetable'] ['Leaf_vegetables']
# wikiTypes:  Upper_limb_anatomy;Joints;
# ['BodyJoint'] ['Upper_limb_anatomy', 'Joints']
# wikiTypes:  Chemical_elements;Breathing_gases;
# ['ElementalSubstance'] ['Chemical_elements', 'Breathing_gases']
# wikiTypes:  Politics_by_issue;Violence;National_security;
# ['ViolentContest'] ['Politics_by_issue', 'Violence', 'National_security']
# wikiTypes:  Crime_by_type;
# ['Destruction', 'Combustion'] ['Crime_by_type']
# wikiTypes:  Chemical_elements;
# ['ElementalSubstance'] ['Chemical_elements']
# wikiTypes:  Analytical_chemistry;Separation_processes;Laboratory_techniques;
# ['Separating'] ['Analytical_chemistry', 'Separation_processes', 'Laboratory_techniques']
# wikiTypes:  Foot;
# ['BodyJoint'] ['Foot']
# wikiTypes:  Health_care;Health_sciences;Branches_of_biology;
# ['BiologicallyActiveSubstance'] ['Health_care', 'Health_sciences', 'Branches_of_biology']
# wikiTypes:  Days_of_the_week;
# ['Day'] ['Days_of_the_week']
# wikiTypes:  Chemical_elements;
# ['ElementalSubstance'] ['Chemical_elements']
# wikiTypes:  Chemical_elements;
# ['ElementalSubstance'] ['Chemical_elements']
# wikiTypes:  Chemical_elements;
# ['ElementalSubstance'] ['Chemical_elements']
# wikiTypes:  Food_and_drink_preparation;
# ['Making'] ['Food_and_drink_preparation']
# wikiTypes:  Building_materials;Soil;Sediments;
# ['Soil'] ['Building_materials', 'Soil', 'Sediments']
# wikiTypes:  Days_of_the_week;
# ['Day'] ['Days_of_the_week']
# wikiTypes:  Exocrine_system;Digestive_system;
# ['AnimalAnatomicalStructure', 'Organ'] ['Exocrine_system', 'Digestive_system']
# wikiTypes:  Virtue;Philanthropy;Simple_living;
# ['ChangeOfPossession'] ['Virtue', 'Philanthropy', 'Simple_living']
# wikiTypes:  Chemical_elements;
# ['ElementalSubstance'] ['Chemical_elements']
# wikiTypes:  Manufactured_goods;
# ['Artifact'] ['Manufactured_goods']
# wikiTypes:  Societal_collapse;Determinants_of_health;
# ['SocialInteraction'] ['Societal_collapse', 'Determinants_of_health']
# wikiTypes:  Capital_punishment;Killings_by_type;
# ['Killing'] ['Capital_punishment', 'Killings_by_type']
# wikiTypes:  Days_of_the_week;
# ['Day'] ['Days_of_the_week']
# wikiTypes:  Structure;Abstraction;
# ['Directing'] ['Structure', 'Abstraction']
# wikiTypes:  Vigilantism;Human_rights_abuses;Crimes;
# ['Killing'] ['Vigilantism', 'Human_rights_abuses', 'Crimes']
# wikiTypes:  Water_sports;Athletic_sports;Racing;Individual_sports;
# ['BodyMotion'] ['Water_sports', 'Athletic_sports', 'Racing', 'Individual_sports']
# wikiTypes:  Chemical_elements;
# ['ElementalSubstance'] ['Chemical_elements']
# wikiTypes:  Songs;Poetry_by_genre;
# ['Text'] ['Songs', 'Poetry_by_genre']
# wikiTypes:  Water_in_culture;Leisure_activities;Hygiene;
# ['Washing'] ['Water_in_culture', 'Leisure_activities', 'Hygiene']
# wikiTypes:  Spices;
# ['Spice'] ['Spices']
# wikiTypes:  Psychrometrics;Atmospheric_optical_phenomena;
# ['WaterCloud'] ['Psychrometrics', 'Atmospheric_optical_phenomena']
# wikiTypes:  Main_topic_classifications;
# ['CommercialAgent'] ['Main_topic_classifications']
# wikiTypes:  Chemical_elements;
# ['ElementalSubstance'] ['Chemical_elements']
# wikiTypes:  Ball_and_bat_games;Precision_sports;Outdoor_recreation;Summer_sports;Individual_sports;
# ['Sport'] ['Ball_and_bat_games', 'Precision_sports', 'Outdoor_recreation', 'Summer_sports', 'Individual_sports']
# wikiTypes:  Combat_sports;Individual_sports;
# ['Sport', 'ViolentContest'] ['Combat_sports', 'Individual_sports']
# wikiTypes:  Cereals;Starch;Food_ingredients;
# ['PreparedFood', 'Powder'] ['Cereals', 'Starch', 'Food_ingredients']
# wikiTypes:  Upper_limb_anatomy;
# ['BodyPart', 'AnimalAnatomicalStructure'] ['Upper_limb_anatomy']
# wikiTypes:  Lower_limb_anatomy;
# ['BodyPart', 'AnimalAnatomicalStructure'] ['Lower_limb_anatomy']
# wikiTypes:  Chemical_elements;
# ['ElementalSubstance'] ['Chemical_elements']
# wikiTypes:  Physical_exercise;
# ['Ambulating'] ['Physical_exercise']
# wikiTypes:  Natural_materials;Regolith;
# ['Mixture'] ['Natural_materials', 'Regolith']
# wikiTypes:  Chemical_elements;
# ['ElementalSubstance'] ['Chemical_elements']
# wikiTypes:  Pathology;
# ['AbnormalAnatomicalStructure'] ['Pathology']
# wikiTypes:  Physical_exercise;Athletic_sports;
# ['BodyMotion', 'MotionUpward'] ['Physical_exercise', 'Athletic_sports']
# wikiTypes:  Meat;
# ['Meat'] ['Meat']
# wikiTypes:  Habits;Determinants_of_health;
# ['RecreationOrExercise'] ['Habits', 'Determinants_of_health']
# wikiTypes:  Philosophy;
# ['ClassificationScheme'] ['Philosophy']
# wikiTypes:  Chemical_elements;
# ['ElementalSubstance'] ['Chemical_elements']
# wikiTypes:  Chemical_elements;
# ['ElementalSubstance'] ['Chemical_elements']
# wikiTypes:  Dairy_products;World_cuisine;
# ['PreparedFood', 'DairyProduct'] ['Dairy_products', 'World_cuisine']
# wikiTypes:  Strength_athletics;Physical_culture;Weight_training;Individual_sports;
# ['Sport'] ['Strength_athletics', 'Physical_culture', 'Weight_training', 'Individual_sports']
# wikiTypes:  Urinary_system;Endocrine_system;
# ['AnimalAnatomicalStructure', 'Organ'] ['Urinary_system', 'Endocrine_system']
# wikiTypes:  Main_topic_classifications;Culture;
# ['LinguisticExpression'] ['Main_topic_classifications', 'Culture']
# wikiTypes:  Work;Personal_life;Labor;
# ['ServiceContract', 'FinancialContract'] ['Work', 'Personal_life', 'Labor']
# wikiTypes:  Government_aid_programs;
# ['Funding'] ['Government_aid_programs']
# wikiTypes:  Animal_anatomy;Facial_features;
# ['BodyPart', 'AnimalAnatomicalStructure'] ['Animal_anatomy', 'Facial_features']
# wikiTypes:  Leptons;Electricity;Molecular_physics;Atomic_physics;
# ['SubatomicParticle'] ['Leptons', 'Electricity', 'Molecular_physics', 'Atomic_physics']
# wikiTypes:  Freight_transport;
# ['Transportation'] ['Freight_transport']
# wikiTypes:  Exocrine_system;Digestive_system;Endocrine_system;
# ['Gland'] ['Exocrine_system', 'Digestive_system', 'Endocrine_system']
# wikiTypes:  Months;
# ['Month'] ['Months']
# wikiTypes:  Public_speaking;Political_communication;Hobbies;
# ['LinguisticCommunication', 'Contest'] ['Public_speaking', 'Political_communication', 'Hobbies']
# wikiTypes:  Nisan_observances;Three_Pilgrimage_Festivals;
# ['MoveableHoliday', 'JewishHoliday'] ['Nisan_observances', 'Three_Pilgrimage_Festivals']
# wikiTypes:  Gemstones;Superhard_materials;
# ['Mineral', 'Carbon'] ['Gemstones', 'Superhard_materials']
# wikiTypes:  Chemical_elements;
# ['ElementalSubstance'] ['Chemical_elements']
# wikiTypes:  Chemical_elements;Coolants;
# ['ElementalSubstance'] ['Chemical_elements', 'Coolants']
# wikiTypes:  Ball_games;Athletic_sports;Team_sports;
# ['TeamSport'] ['Ball_games', 'Athletic_sports', 'Team_sports']
# wikiTypes:  Chemical_elements;
# ['ElementalSubstance'] ['Chemical_elements']
# wikiTypes:  Joining;Concrete;
# ['CompoundSubstance', 'ManufacturedProduct'] ['Joining', 'Concrete']
# wikiTypes:  Gravity;
# ['Translocation', 'MotionDownward'] ['Gravity']
# wikiTypes:  Control_theory;Waves;
# ['NaturalProcess'] ['Control_theory', 'Waves']
# wikiTypes:  Chemical_elements;
# ['ElementalSubstance'] ['Chemical_elements']
# wikiTypes:  Engineering_thermodynamics;
# ['Removing'] ['Engineering_thermodynamics']
# wikiTypes:  Body_Regions;
# ['BodyPart', 'AnimalAnatomicalStructure'] ['Body_Regions']
# wikiTypes:  Human_anatomy_by_organ;Central_nervous_system;
# ['AnimalAnatomicalStructure', 'Organ'] ['Human_anatomy_by_organ', 'Central_nervous_system']
# wikiTypes:  Chemical_elements;
# ['ElementalSubstance'] ['Chemical_elements']
# wikiTypes:  Toxicology;Minerals;Fibers;
# ['Mineral'] ['Toxicology', 'Minerals', 'Fibers']
# wikiTypes:  Meat;
# ['Bird', 'Livestock'] ['Meat']
# wikiTypes:  Respiratory_system;
# ['AnimalAnatomicalStructure', 'Organ'] ['Respiratory_system']
# wikiTypes:  Polysaccharides;
# ['Carbohydrate', 'PlantSubstance'] ['Polysaccharides']
# wikiTypes:  Freshwater_crustaceans;
# ['Shellfish'] ['Freshwater_crustaceans']
# wikiTypes:  Chemical_elements;
# ['ElementalSubstance'] ['Chemical_elements']
# wikiTypes:  Mental_and_behavioural_disorders;Abnormal_psychology;
# ['PsychologicalDysfunction'] ['Mental_and_behavioural_disorders', 'Abnormal_psychology']
# wikiTypes:  Chemical_elements;
# ['ElementalSubstance'] ['Chemical_elements']
# wikiTypes:  Inflammations;
# ['ViralDisease'] ['Inflammations']
# wikiTypes:  Months;
# ['Month'] ['Months']
# wikiTypes:  Consumer_theory;Concepts_in_ethics;Ethical_principles;Rational_choice_theory;
# ['ComputerProgram'] ['Consumer_theory', 'Concepts_in_ethics', 'Ethical_principles', 'Rational_choice_theory']
# wikiTypes:  Culture;
# ['ChangeOfPossession'] ['Culture']
# wikiTypes:  Medical_specialties;
# ['TherapeuticProcess'] ['Medical_specialties']
# wikiTypes:  National_security;Crimes;Information_sensitivity;
# ['Investigating', 'PoliticalProcess'] ['National_security', 'Crimes', 'Information_sensitivity']
# wikiTypes:  Hunting_methods;Hunting_legislation;Environmental_crime;Illegal_occupations;
# ['Killing'] ['Hunting_methods', 'Hunting_legislation', 'Environmental_crime', 'Illegal_occupations']
# wikiTypes:  Geometric_measurement;
# ['SocialRole'] ['Geometric_measurement']
# wikiTypes:  Percussion;Rhythm_and_meter;
# ['Demonstrating', 'RadiatingSound'] ['Percussion', 'Rhythm_and_meter']
# wikiTypes:  Oils;Fossil_fuels;
# ['PetroleumProduct'] ['Oils', 'Fossil_fuels']
# wikiTypes:  Ball_and_bat_games;Athletic_sports;Summer_sports;Team_sports;
# ['TeamSport'] ['Ball_and_bat_games', 'Athletic_sports', 'Summer_sports', 'Team_sports']
# wikiTypes:  Edible_fruits;
# ['Fruit'] ['Edible_fruits']
# wikiTypes:  Tropical_fruit;Edible_fruits;
# ['FruitOrVegetable', 'TropicalFruit'] ['Tropical_fruit', 'Edible_fruits']
# wikiTypes:  Rural_culture;Agriculture_by_type;Domesticated_animals;
# ['DomesticAnimal'] ['Rural_culture', 'Agriculture_by_type', 'Domesticated_animals']
# wikiTypes:  Christian_fasting;
# ['MoveableHoliday', 'ChristianHoliday'] ['Christian_fasting']
# wikiTypes:  Problem_behavior;Crimes;
# ['Destruction'] ['Problem_behavior', 'Crimes']
# wikiTypes:  Lower_limb_anatomy;Joints;
# ['BodyJoint'] ['Lower_limb_anatomy', 'Joints']
# wikiTypes:  Months;
# ['Month'] ['Months']
# wikiTypes:  Environmental_issues_with_soil;Environmental_impact_of_agriculture;Deserts;
# ['WeatherProcess'] ['Environmental_issues_with_soil', 'Environmental_impact_of_agriculture', 'Deserts']
# wikiTypes:  Linguistics;
# ['Procedure'] ['Linguistics']
# wikiTypes:  Web_technology;
# ['StandardIdentifier', 'WebAddress'] ['Web_technology']
# wikiTypes:  Chemical_elements;
# ['ElementalSubstance'] ['Chemical_elements']
# wikiTypes:  Nucleons;
# ['SubatomicParticle'] ['Nucleons']
# wikiTypes:  Noble_gases;Chemical_elements;
# ['ElementalSubstance'] ['Noble_gases', 'Chemical_elements']
# wikiTypes:  Main_topic_classifications;
# ['GovernmentOrganization'] ['Main_topic_classifications']
# wikiTypes:  Dairy_products;Condiments;Cooking_fats;
# ['PreparedFood', 'DairyProduct'] ['Dairy_products', 'Condiments', 'Cooking_fats']
# wikiTypes:  Chemical_elements;
# ['ElementalSubstance'] ['Chemical_elements']
# wikiTypes:  Writing;
# ['LinguisticExpression', 'Artifact', 'ContentBearingObject'] ['Writing']
# wikiTypes:  Ferrous_alloys;Metals;Iron;
# ['MetallicAlloy', 'MetalProduct'] ['Ferrous_alloys', 'Metals', 'Iron']
# wikiTypes:  Noble_gases;Chemical_elements;
# ['ElementalSubstance'] ['Noble_gases', 'Chemical_elements']
# wikiTypes:  Arab_culture;Arabic_clothing;Headgear;
# ['Veil'] ['Arab_culture', 'Arabic_clothing', 'Headgear']
# wikiTypes:  Chemical_elements;
# ['ElementalSubstance'] ['Chemical_elements']
# wikiTypes:  Anthropology;
# ['Declaring', 'Ceremony'] ['Anthropology']
# wikiTypes:  Sources_of_knowledge;Intelligence;Cognition;Logic;
# ['IntentionalPsychologicalProcess'] ['Sources_of_knowledge', 'Intelligence', 'Cognition', 'Logic']
# wikiTypes:  Energy_conversion;
# ['Increasing'] ['Energy_conversion']
# wikiTypes:  Poultry_diseases;Respiratory_diseases;
# ['VaccinatableDisease', 'ViralDisease'] ['Poultry_diseases', 'Respiratory_diseases']
# wikiTypes:  Chemical_elements;
# ['ElementalSubstance'] ['Chemical_elements']
# wikiTypes:  Terrestrial_biomes;
# ['Plain', 'Biome', 'ArcticRegion'] ['Terrestrial_biomes']
# wikiTypes:  Humanities;Government;Main_topic_classifications;
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-16-64b6b9632d6b> in <module>
#       2 for concept,sumoTypes,wikiTypes in zip(df_concept['concept'],df_concept['sumoTypes'],df_concept['wikiTypes']):
#       3     print('wikiTypes: ',wikiTypes)
# ----> 4     s_types = [s for s in sumoTypes.split(';') if len(s)>1]
#       5     w_types = [s for s in wikiTypes.split(';') if len(s)>1]
#       6     print(s_types, w_types)
#
# AttributeError: 'float' object has no attribute 'split'
